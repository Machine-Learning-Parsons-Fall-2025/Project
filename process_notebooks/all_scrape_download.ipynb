# %% [markdown]
# # Scraping Kamondb for Kamon crest images + descriptions

# %% [markdown]
# KamonDB (https://kamondb.com/) is a Japanese website (and custom Kamon designer) which hosts a lot of regularly sized Kamon images. These images can be found on their website, sorted into 7 groups:
# - Plant pattern  (the biggest group)
# - Animal crest
# - Vessel crest
# - Architectural pattern
# - Geometric pattern
# - Character pattern
#
# As far I as I can tell, there's no consistent order to the naming of each category and subcategory - these might need to be gathered by hand. However, each page that contains crests and their descriptions is consitently structured:
#  - `<article>` tag (or even more specific, `<table>` tag)contains all elements with crests and descriptions
#     - all crests are stored in `<td>` tags
#     - each crest is an `<img>` and a string with `<font>` tag
#
# Scrape each subpage link from the category directories. Most just have 1 page directories, some have 2.

# %% [markdown]
# ### Scraping all pages

# %%
#Import requests and beautifulsoup4
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import re

# %%
#master list of links to scrape
category_links = [
    "https://kamondb.com/category/plant/", #plants 1 
    "https://kamondb.com/category/plant/page/2/", #plants 2
    "https://kamondb.com/category/animal/", #animals 
    "https://kamondb.com/category/object/", #objects 1
    "https://kamondb.com/category/object/page/2/", #objects 2
    "https://kamondb.com/category/architecture/", #architecture
    "https://kamondb.com/category/nature/", #nature
    "https://kamondb.com/category/geometry/", #geometry
    "https://kamondb.com/category/letter/", #characters
]

# %%
#keeping track of all subcategory hrefs and titles
all_subcategory = []


for url in category_links:

    #get raw html and parse
    raw_html = requests.get(url).content
    soup = BeautifulSoup(raw_html, 'html.parser')
    time.sleep(1)  # polite delay between requests

    #get all a tags in div with id=list
    item_list = soup.find('div', id='list').find_all('a')

    #add tags to a master list of hrefs
    for a in item_list:
        subcat_object = {
            'href': a['href'],
            "title": a["title"],
            "category" : re.search(r"/category/([^/]+)(?:/|$)", url).group(1)  # extract category from URL
        }
        all_subcategory.append(subcat_object)

# %%
all_subcategory

# %%
#for each subcategory link, scrape data and add to a master list
# master list of all items contains:
    # link to image
    # image title
    # subcategory title
    # category title
all_kamon = []

for item in all_subcategory:
    url = item['href']
    subcategory_title = item['title']
    category_title = item['category']

    time.sleep(1)  # polite delay between requests
    try: 
        #get raw html and parse
        raw_html = requests.get(url).content
        soup = BeautifulSoup(raw_html, 'html.parser')

        #find the table in each page
        table_elements = soup.table.find_all('td')

        object = {}
        for kamon in table_elements:
            try:
                kamon_object = {
                    'image_link': kamon.img['src'],
                    'description': kamon.get_text().replace('\n', '').strip(),
                    'subcategory_title': subcategory_title,
                    'category_title': category_title
                }
                all_kamon.append(kamon_object)
                print(f"Added kamon: {kamon_object['description']}")
            except:
                print("Kamon Failed to process an item in the table.")
        print(f"Successfully retrieved {url}")
    except:
        print(f"Failed to process {url}")

# %%
all_kamon

# %%
#save kamon data to csv
df = pd.DataFrame(all_kamon)
df.to_csv('data/kamon_data.csv', index=False)

# %% [markdown]
# ## Next Steps:

# %% [markdown]
# - Google translate descriptions and subcategory title
# - download and parse images?
#     - make dimensions equal
# - Machine Learning
#     - Kamon descriptions? text ML? do after class on 11/17
#     - Images by radius from center - visual patterns, image clustering?
#     -

# %%
#download images to local folder

#download images from link in kamon_engdesc_only.csv
    #naming scheme:
    #use category_title_(first word in subcategory_title)_(index).jpg
kamon_df = pd.read_csv('data/kamon_engdesc_only.csv')
kamon_df.head()

#save images to images_kamon
# Out:
#                                           image_link description  \
# 0  https://kamondb.com/wp/wp-content/uploads/2019...         徳川葵
# 1  https://kamondb.com/wp/wp-content/uploads/2019...        剣三つ葵
# 2  https://kamondb.com/wp/wp-content/uploads/2019...         立ち葵
# 3  https://kamondb.com/wp/wp-content/uploads/2019...       丸に立ち葵
# 4  https://kamondb.com/wp/wp-content/uploads/2019...       水に立ち葵
#
#   subcategory_title category_title        English_Description  \
# 0           葵 | あおい          plant               Aoi Tokugawa
# 1           葵 | あおい          plant            sword three Aoi
# 2           葵 | あおい          plant         standing hollyhock
# 3           葵 | あおい          plant   Aoi standing in a circle
# 4           葵 | あおい          plant  Aoi standing in the water
#
#   English_Subcategory_Title English_Subcategory
# 0                 Aoi | Aoi           Aoi | Aoi
# 1                 Aoi | Aoi           Aoi | Aoi
# 2                 Aoi | Aoi           Aoi | Aoi
# 3                 Aoi | Aoi           Aoi | Aoi
# 4                 Aoi | Aoi           Aoi | Aoi

# %%
#drop English_Subcatergory_Title column
kamon_df = kamon_df.drop(columns=['English_Subcategory_Title'])

# %%
#change column names to lowercase
kamon_df.columns = [col.lower() for col in kamon_df.columns]
kamon_df.head()
# Out:
#                                           image_link description  \
# 0  https://kamondb.com/wp/wp-content/uploads/2019...         徳川葵
# 1  https://kamondb.com/wp/wp-content/uploads/2019...        剣三つ葵
# 2  https://kamondb.com/wp/wp-content/uploads/2019...         立ち葵
# 3  https://kamondb.com/wp/wp-content/uploads/2019...       丸に立ち葵
# 4  https://kamondb.com/wp/wp-content/uploads/2019...       水に立ち葵
#
#   subcategory_title category_title        english_description  \
# 0           葵 | あおい          plant               Aoi Tokugawa
# 1           葵 | あおい          plant            sword three Aoi
# 2           葵 | あおい          plant         standing hollyhock
# 3           葵 | あおい          plant   Aoi standing in a circle
# 4           葵 | あおい          plant  Aoi standing in the water
#
#   english_subcategory
# 0           Aoi | Aoi
# 1           Aoi | Aoi
# 2           Aoi | Aoi
# 3           Aoi | Aoi
# 4           Aoi | Aoi

# %% [markdown]
# There are a lot of random characters I don't want in the filenames. Removing those here. Annoyingly, both the normal | and the japanese | are present, so I have to make sure to remove both of them. Also, slashes /, commas, and quotation marks are removed.

# %%
#for english_subcategory, | replaced with underscores
kamon_df['english_subcategory'] = kamon_df['english_subcategory'].str.replace(r'\s*\|\s*', '_', regex=True)
#also, replace the japanese full-width vertical bar (U+FF5C) with underscores
kamon_df['english_subcategory'] = kamon_df['english_subcategory'].str.replace(r'\s*｜\s*', '_', regex=True)

#turn all / or spaces into underscores
kamon_df['english_subcategory'] = kamon_df['english_subcategory'].str.replace(r'[\s/]+', '_', regex=True)
#remove all commas from english subcategory
kamon_df['english_subcategory'] = kamon_df['english_subcategory'].str.replace(',', '', regex=False)
#remove all quotation marks from english subcategory
kamon_df['english_subcategory'] = kamon_df['english_subcategory'].str.replace('"', '', regex=False)

#make everything lowercase
kamon_df['english_subcategory'] = kamon_df['english_subcategory'].str.lower()
#if there are any cases where the category repeats itself, remove the repetition
kamon_df['english_subcategory'] = kamon_df['english_subcategory'].apply(
    lambda x: re.sub(r'\b(\w+)(_\1)+\b', r'\1', x)
)

kamon_df.head()
# Out:
#                                           image_link description  \
# 0  https://kamondb.com/wp/wp-content/uploads/2019...         徳川葵
# 1  https://kamondb.com/wp/wp-content/uploads/2019...        剣三つ葵
# 2  https://kamondb.com/wp/wp-content/uploads/2019...         立ち葵
# 3  https://kamondb.com/wp/wp-content/uploads/2019...       丸に立ち葵
# 4  https://kamondb.com/wp/wp-content/uploads/2019...       水に立ち葵
#
#   subcategory_title category_title        english_description  \
# 0           葵 | あおい          plant               Aoi Tokugawa
# 1           葵 | あおい          plant            sword three Aoi
# 2           葵 | あおい          plant         standing hollyhock
# 3           葵 | あおい          plant   Aoi standing in a circle
# 4           葵 | あおい          plant  Aoi standing in the water
#
#   english_subcategory
# 0                 aoi
# 1                 aoi
# 2                 aoi
# 3                 aoi
# 4                 aoi

# %%
kamon_df.iloc[1908]
kamon_df.iloc[3568]
kamon_df.iloc[3565]
# Out:
# image_link             https://kamondb.com/wp/wp-content/uploads/2019...
# description                                                        一つ瓢の丸
# subcategory_title                                     瓢・瓢箪｜ひょう・ひょうたん・ひさご
# category_title                                                     plant
# english_description                                     One gourd circle
# english_subcategory                         gourd_gourd_hyo_gourd_hisago
# Name: 1908, dtype: object

# %%
#test to make sure splitting is happening correctly
kamon_df.iloc[372]["english_subcategory"]
kamon_df.iloc[3568]["english_subcategory"]
# Out:
# 'arrow_ya'

# %%
#all
kamon_df['image_filename'] = ''

# Group by subcategory and process each group separately
for subcategory, group in kamon_df.groupby('english_subcategory'):
    for idx, row in group.iterrows():
        image_url = row['image_link']
        category_title = row['category_title']
        subcategory_first_word = row['english_subcategory'].split()[0]
        image_name = f"{category_title}_{subcategory_first_word}_{idx % len(group)}.jpg"  # Reset index within group
        
        try:
            image_data = requests.get(image_url).content
            with open(f'Data/images_kamon/{image_name}', 'wb') as handler:
                handler.write(image_data)
            print(f"Downloaded {image_name}")
            kamon_df.at[idx, 'image_filename'] = image_name
        except:
            print(f"Failed to download image from {image_url}")
# Out:
# Downloaded object_ace_masakari_4.jpg
# Downloaded object_ace_masakari_5.jpg
# Downloaded object_ace_masakari_6.jpg
# Downloaded object_ace_masakari_7.jpg
# Downloaded object_ace_masakari_8.jpg
# Downloaded object_ace_masakari_0.jpg
# Downloaded object_ace_masakari_1.jpg
# Downloaded object_ace_masakari_2.jpg
# Downloaded object_ace_masakari_3.jpg
# Downloaded object_anchor_7.jpg
# Downloaded object_anchor_8.jpg
# Downloaded object_anchor_9.jpg
# Downloaded object_anchor_10.jpg
# Downloaded object_anchor_0.jpg
# Downloaded object_anchor_1.jpg
# Downloaded object_anchor_2.jpg
# Downloaded object_anchor_3.jpg
# Downloaded object_anchor_4.jpg
# Downloaded object_anchor_5.jpg
# Downloaded object_anchor_6.jpg
# Downloaded animal_antlers_deer_antlers_tsuno_shika_kazuno
# Downloaded architecture_torii_1.jpg
# Downloaded architecture_torii_2.jpg
# Downloaded architecture_torii_3.jpg
# Downloaded architecture_torii_4.jpg
# Downloaded architecture_torii_5.jpg
# Downloaded object_treasure_knot_takaramusubi_0.jpg
# Downloaded object_treasure_knot_takaramusubi_1.jpg
# Downloaded object_treasure_knot_takaramusubi_2.jpg
# Downloaded object_treasure_knot_takaramusubi_3.jpg
# Downloaded object_treasure_knot_takaramusubi_4.jpg
# Downloaded object_treasure_knot_takaramusubi_5.jpg
# Downloaded object_tree_ki_4.jpg
# Downloaded object_tree_ki_5.jpg
# Downloaded object_tree_ki_6.jpg
# Downloaded object_tree_ki_0.jpg
# Downloaded object_tree_ki_1.jpg
# Downloaded object_tree_ki_2.jpg
# Downloaded object_tree_ki_3.jpg
# Downloaded object_tsuzumi_3.jpg
# Downloaded object_tsuzumi_0.jpg
# Downloaded object_tsuzumi_1.jpg
# Downloaded object_tsuzumi_2.jpg
# Downloaded animal_turtle_0.jpg
# Downloaded geometry_turtle_shell_56.jpg
# Downloaded geometry_turtle_shell_57.jpg
# Downloaded geometry_turtle_shell_58.jpg
# Downloaded geometry_turtle_shell_59.jpg
# Downloaded geometry_turtle_shell_60.jpg
# Downloaded geometry_turtle_shell_61.jpg
# Downloaded geometry_turtle_shell_62.jpg
# Downloaded geometry_turtle_shell_63.jpg
# Downloaded geometry_turtle_shell_64.jpg
# Downloaded geometry_turtle_shell_65.jpg
# Downloaded geometry_turtle_shell_66.jpg
# Downloaded geometry_turtle_shell_67.jpg
# Downloaded geometry_turtle_shell_68.jpg
# Downloaded geometry_turtle_shell_69.jpg
# Downloaded geometry_turtle_shell_70.jpg
# Downloaded geometry_turtle_shell_71.jpg
# Downloaded geometry_turtle_shell_72.jpg
# Downloaded geometry_turtle_shell_73.jpg
# Downloaded geometry_turtle_shell_74.jpg
# Downloaded geometry_turtle_shell_75.jpg
# Downloaded geometry_turtle_shell_76.jpg
# Downloaded geometry_turtle_shell_77.jpg
# Downloaded geometry_turtle_shell_78.jpg
# Downloaded geometry_turtle_shell_79.jpg
# Downloaded geometry_turtle_shell_80.jpg
# Downloaded geometry_turtle_shell_81.jpg
# Downloaded geometry_turtle_shell_82.jpg
# Downloaded geometry_turtle_shell_83.jpg
# Downloaded geometry_turtle_shell_84.jpg
# Downloaded geometry_turtle_shell_85.jpg
# Downloaded geometry_turtle_shell_86.jpg
# Downloaded geometry_turtle_shell_87.jpg
# Downloaded geometry_turtle_shell_88.jpg
# Downloaded geometry_turtle_shell_89.jpg
# Downloaded geometry_turtle_shell_0.jpg
# Downloaded geometry_turtle_shell_1.jpg
# Downloaded geometry_turtle_shell_2.jpg
# Downloaded geometry_turtle_shell_3.jpg
# Downloaded geometry_turtle_shell_4.jpg
# Downloaded geometry_turtle_shell_5.jpg
# Downloaded geometry_turtle_shell_6.jpg
# Downloaded geometry_turtle_shell_7.jpg
# Downloaded geometry_turtle_shell_8.jpg
# Downloaded geometry_turtle_shell_9.jpg
# Downloaded geometry_turtle_shell_10.jpg
# Downloaded geometry_turtle_shell_11.jpg
# Downloaded geometry_turtle_shell_12.jpg
# Downloaded geometry_turtle_shell_13.jpg
# Downloaded geometry_turtle_shell_14.jpg
# Downloaded geometry_turtle_shell_15.jpg
# Downloaded geometry_turtle_shell_16.jpg
# Downloaded geometry_turtle_shell_17.jpg
# Downloaded geometry_turtle_shell_18.jpg
# Downloaded geometry_turtle_shell_19.jpg
# Downloaded geometry_turtle_shell_20.jpg
# Downloaded geometry_turtle_shell_21.jpg
# Downloaded geometry_turtle_shell_22.jpg
# Downloaded geometry_turtle_shell_23.jpg
# Downloaded geometry_turtle_shell_24.jpg
# Downloaded geometry_turtle_shell_25.jpg
# Downloaded geometry_turtle_shell_26.jpg
# Downloaded geometry_turtle_shell_27.jpg
# Downloaded geometry_turtle_shell_28.jpg
# Downloaded geometry_turtle_shell_29.jpg
# Downloaded geometry_turtle_shell_30.jpg
# Downloaded geometry_turtle_shell_31.jpg
# Downloaded geometry_turtle_shell_32.jpg
# Downloaded geometry_turtle_shell_33.jpg
# Downloaded geometry_turtle_shell_34.jpg
# Downloaded geometry_turtle_shell_35.jpg
# Downloaded geometry_turtle_shell_36.jpg
# Downloaded geometry_turtle_shell_37.jpg
# Downloaded geometry_turtle_shell_38.jpg
# Downloaded geometry_turtle_shell_39.jpg
# Downloaded geometry_turtle_shell_40.jpg
# Downloaded geometry_turtle_shell_41.jpg
# Downloaded geometry_turtle_shell_42.jpg
# Downloaded geometry_turtle_shell_43.jpg
# Downloaded geometry_turtle_shell_44.jpg
# Downloaded geometry_turtle_shell_45.jpg
# Downloaded geometry_turtle_shell_46.jpg
# Downloaded geometry_turtle_shell_47.jpg
# Downloaded geometry_turtle_shell_48.jpg
# Downloaded geometry_turtle_shell_49.jpg
# Downloaded geometry_turtle_shell_50.jpg
# Downloaded geometry_turtle_shell_51.jpg
# Downloaded geometry_turtle_shell_52.jpg
# Downloaded geometry_turtle_shell_53.jpg
# Downloaded geometry_turtle_shell_54.jpg
# Downloaded geometry_turtle_shell_55.jpg
# Downloaded plant_violet_sumire_0.jpg
# Downloaded plant_violet_sumire_1.jpg
# Downloaded plant_violet_sumire_2.jpg
# Downloaded plant_violet_sumire_3.jpg
# Downloaded plant_violet_sumire_4.jpg
# Downloaded plant_walnut_3.jpg
# Downloaded plant_walnut_4.jpg
# Downloaded plant_walnut_0.jpg
# Downloaded plant_walnut_1.jpg
# Downloaded plant_walnut_2.jpg
# Downloaded plant_warabi_2.jpg
# Downloaded plant_warabi_3.jpg
# Downloaded plant_warabi_4.jpg
# Downloaded plant_warabi_5.jpg
# Downloaded plant_warabi_0.jpg
# Downloaded plant_warabi_1.jpg
# Downloaded nature_wave_wami_nami_4.jpg
# Downloaded nature_wave_wami_nami_5.jpg
# Downloaded nature_wave_wami_nami_6.jpg
# Downloaded nature_wave_wami_nami_7.jpg
# Downloaded nature_wave_wami_nami_8.jpg
# Downloaded nature_wave_wami_nami_9.jpg
# Downloaded plant_yugao_2.jpg
# Downloaded plant_yugao_0.jpg
# Downloaded plant_yugao_1.jpg
# Downloaded object_轡_bridle_11.jpg
# Downloaded object_轡_bridle_12.jpg
# Downloaded object_轡_bridle_13.jpg
# Downloaded object_轡_bridle_14.jpg
# Downloaded object_轡_bridle_15.jpg
# Downloaded object_轡_bridle_16.jpg
# Downloaded object_轡_bridle_17.jpg
# Downloaded object_轡_bridle_18.jpg
# Downloaded object_轡_bridle_19.jpg
# Downloaded object_轡_bridle_20.jpg
# Downloaded object_轡_bridle_21.jpg
# Downloaded object_轡_bridle_22.jpg
# Downloaded object_轡_bridle_23.jpg
# Downloaded object_轡_bridle_0.jpg
# Downloaded object_轡_bridle_1.jpg
# Downloaded object_轡_bridle_2.jpg
# Downloaded object_轡_bridle_3.jpg
# Downloaded object_轡_bridle_4.jpg
# Downloaded object_轡_bridle_5.jpg
# Downloaded object_轡_bridle_6.jpg
# Downloaded object_轡_bridle_7.jpg
# Downloaded object_轡_bridle_8.jpg
# Downloaded object_轡_bridle_9.jpg
# Downloaded object_轡_bridle_10.jpg

# %%
#check which images failed to download - see if image_filename is empty
failed_downloads = kamon_df[kamon_df['image_filename'] == '']
failed_downloads
#empty, so all worked
# Out:
# Empty DataFrame
# Columns: [image_link, description, subcategory_title, category_title, english_description, english_subcategory, image_filename]
# Index: []

# %%
#check filenames in images_kamon folder against kamon_df image_filename column
import os
image_files = set(os.listdir('Data/images_kamon'))
kamon_column = set(kamon_df['image_filename'])
#check where these two sets differ
missing_in_folder = kamon_column - image_files
missing_in_folder
missing_in_dataframe = image_files - kamon_column
missing_in_dataframe
#all ok?
# Out:
# {'.DS_Store'}

# %% [markdown]
# I'm not fully convinved, but this should be all the images.
# 5359 total images, 5359 total rows.

# %%
#export dataframe to new csv
kamon_df.to_csv('data/kamon.csv', index=False)

# %%
#import the new kamon.csv and display head
kamon_df = pd.read_csv('data/kamon.csv')
kamon_df.head()
# Out:
#                                           image_link description  \
# 0  https://kamondb.com/wp/wp-content/uploads/2019...         徳川葵
# 1  https://kamondb.com/wp/wp-content/uploads/2019...        剣三つ葵
# 2  https://kamondb.com/wp/wp-content/uploads/2019...         立ち葵
# 3  https://kamondb.com/wp/wp-content/uploads/2019...       丸に立ち葵
# 4  https://kamondb.com/wp/wp-content/uploads/2019...       水に立ち葵
#
#   subcategory_title category_title        english_description  \
# 0           葵 | あおい          plant               Aoi Tokugawa
# 1           葵 | あおい          plant            sword three Aoi
# 2           葵 | あおい          plant         standing hollyhock
# 3           葵 | あおい          plant   Aoi standing in a circle
# 4           葵 | あおい          plant  Aoi standing in the water
#
#   english_subcategory   image_filename
# 0                 aoi  plant_aoi_0.jpg
# 1                 aoi  plant_aoi_1.jpg
# 2                 aoi  plant_aoi_2.jpg
# 3                 aoi  plant_aoi_3.jpg
# 4                 aoi  plant_aoi_4.jpg

# %%
#get random sample of 10% of image_filenames
sample_df = kamon_df.sample(n=540, random_state=42)
sample_df["image_filename"]
# Out:
# 2833              object_fan_45.jpg
# 3967    nature_wave_wami_nami_7.jpg
# 401     plant_sawata_omodaka_73.jpg
# 2638      animal_crane_tsuru_38.jpg
# 2005             plant_peony_10.jpg
#                    ...
# 3125         object_sword_ken_5.jpg
# 1580               plant_ivy_92.jpg
# 1666         plant_pear_none_10.jpg
# 1730          plant_hanakaku_28.jpg
# 3407            object_ladder_3.jpg
# Name: image_filename, Length: 540, dtype: object

# %%
#copy random sample to random_subset folder
import os
for filename in sample_df["image_filename"]:
    src_path = os.path.join('Data/images_kamon', filename)
    dest_path = os.path.join('Data/random_subset', filename)
    try:
        with open(src_path, 'rb') as src_file:
            with open(dest_path, 'wb') as dest_file:
                dest_file.write(src_file.read())
        print(f"Copied {filename} to random_subset.")
    except FileNotFoundError:
        print(f"File {filename} not found in images_kamon.")
# Out:
# Copied object_fan_45.jpg to random_subset.
# Copied nature_wave_wami_nami_7.jpg to random_subset.
# Copied plant_sawata_omodaka_73.jpg to random_subset.
# Copied animal_crane_tsuru_38.jpg to random_subset.
# Copied plant_peony_10.jpg to random_subset.
# Copied plant_hemp_asa_16.jpg to random_subset.
# Copied plant_melon_uri_94.jpg to random_subset.
# Copied geometry_meyui_61.jpg to random_subset.
# Copied plant_chouji_32.jpg to random_subset.
# Copied architecture_izutsu_46.jpg to random_subset.
# Copied geometry_corner_write_62.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_51.jpg to random_subset.
# Copied object_car_5.jpg to random_subset.
# Copied object_mari_scissors_2.jpg to random_subset.
# Copied geometry_ring:_other_wa_50.jpg to random_subset.
# Copied plant_chrysanthemum_hear_2.jpg to random_subset.
# Copied geometry_ring:_middle_ring_nakawa_15.jpg to random_subset.
# Copied plant_kikyo_30.jpg to random_subset.
# Copied animal_crane_tsuru_44.jpg to random_subset.
# Copied object_apricot_leaves_22.jpg to random_subset.
# Copied plant_kikyo_41.jpg to random_subset.
# Copied nature_moon_tsuki_17.jpg to random_subset.
# Copied object_apricot_leaves_9.jpg to random_subset.
# Copied plant_sasa_52.jpg to random_subset.
# Copied geometry_corner_write_20.jpg to random_subset.
# Copied object_arrowhead_yajiri_3.jpg to random_subset.
# Copied object_apricot_leaves_15.jpg to random_subset.
# Copied geometry_matsubabishi_matsukawabishi_2.jpg to random_subset.
# Copied plant_chami_chanomi_32.jpg to random_subset.
# Copied plant_sakura_61.jpg to random_subset.
# Copied geometry_tomoe_95.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_91.jpg to random_subset.
# Copied geometry_corner_write_25.jpg to random_subset.
# Copied architecture_rokuyo_rokuyou_0.jpg to random_subset.
# Copied letter_characters_moji_68.jpg to random_subset.
# Copied geometry_turtle_shell_84.jpg to random_subset.
# Copied plant_chouji_8.jpg to random_subset.
# Copied plant_plum_99.jpg to random_subset.
# Copied geometry_ring:_itowa_itowa_71.jpg to random_subset.
# Copied plant_sasa_63.jpg to random_subset.
# Copied geometry_hiki_26.jpg to random_subset.
# Copied geometry_aya_ukisen_ryo_fusen_45.jpg to random_subset.
# Copied plant_kikyo_35.jpg to random_subset.
# Copied geometry_hishi_54.jpg to random_subset.
# Copied geometry_ring:_itowa_itowa_25.jpg to random_subset.
# Copied plant_aoi_8.jpg to random_subset.
# Copied object_sword_ken_95.jpg to random_subset.
# Copied plant_ivy_73.jpg to random_subset.
# Copied animal_hawk_feather_takanoha_32.jpg to random_subset.
# Copied plant_sawata_omodaka_8.jpg to random_subset.
# Copied object_paddle_0.jpg to random_subset.
# Copied geometry_turtle_shell_39.jpg to random_subset.
# Copied object_kanawa_11.jpg to random_subset.
# Copied plant_hanabishi_110.jpg to random_subset.
# Copied plant_pine_matsu_44.jpg to random_subset.
# Copied object_chai_board_beating_board_chohan_4.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_103.jpg to random_subset.
# Copied geometry_tomoe_1.jpg to random_subset.
# Copied plant_kashiwa_69.jpg to random_subset.
# Copied geometry_hishi_68.jpg to random_subset.
# Copied animal_crane_tsuru_1.jpg to random_subset.
# Copied nature_suhama_39.jpg to random_subset.
# Copied plant_melon_uri_83.jpg to random_subset.
# Copied plant_hanabishi_82.jpg to random_subset.
# Copied plant_maple_maple_momiji_0.jpg to random_subset.
# Copied animal_crane_tsuru_47.jpg to random_subset.
# Copied geometry_ring:_middle_ring_nakawa_64.jpg to random_subset.
# Copied geometry_meyui_19.jpg to random_subset.
# Copied geometry_ring:_hosowa_hosowa_17.jpg to random_subset.
# Copied plant_plum_108.jpg to random_subset.
# Copied geometry_turtle_shell_74.jpg to random_subset.
# Copied plant_kikyo_109.jpg to random_subset.
# Copied geometry_turtle_shell_49.jpg to random_subset.
# Copied geometry_ring:_other_wa_13.jpg to random_subset.
# Copied plant_ginkgo_14.jpg to random_subset.
# Copied nature_star_hoshi_14.jpg to random_subset.
# Copied plant_denjiso_3.jpg to random_subset.
# Copied geometry_hiki_28.jpg to random_subset.
# Copied object_money_hei_3.jpg to random_subset.
# Copied geometry_hiki_15.jpg to random_subset.
# Copied geometry_turtle_shell_37.jpg to random_subset.
# Copied letter_characters_moji_53.jpg to random_subset.
# Copied object_轡_bridle_15.jpg to random_subset.
# Copied animal_sparrow_6.jpg to random_subset.
# Copied plant_palm_0.jpg to random_subset.
# Copied plant_hanabishi_55.jpg to random_subset.
# Copied plant_kajikaji_leaf_kaji_9.jpg to random_subset.
# Copied geometry_ring:_hosowa_hosowa_3.jpg to random_subset.
# Copied plant_nadeshiko_1.jpg to random_subset.
# Copied plant_aoi_15.jpg to random_subset.
# Copied plant_ginkgo_9.jpg to random_subset.
# Copied plant_ken_katabami_kenkatabami_13.jpg to random_subset.
# Copied plant_plum_36.jpg to random_subset.
# Copied plant_sakura_29.jpg to random_subset.
# Copied object_sword_ken_98.jpg to random_subset.
# Copied plant_kajikaji_leaf_kaji_8.jpg to random_subset.
# Copied geometry_turtle_shell_72.jpg to random_subset.
# Copied geometry_ring:_middle_ring_nakawa_19.jpg to random_subset.
# Copied plant_chouji_19.jpg to random_subset.
# Copied object_sword_ken_96.jpg to random_subset.
# Copied object_sword_ken_90.jpg to random_subset.
# Copied geometry_corner_write_56.jpg to random_subset.
# Copied geometry_ring:_itowa_itowa_51.jpg to random_subset.
# Copied plant_melon_uri_2.jpg to random_subset.
# Copied plant_hanabishi_22.jpg to random_subset.
# Copied plant_kikyo_68.jpg to random_subset.
# Copied plant_maple_maple_momiji_6.jpg to random_subset.
# Copied geometry_turtle_shell_56.jpg to random_subset.
# Copied plant_hemp_asa_6.jpg to random_subset.
# Copied plant_kiri_52.jpg to random_subset.
# Copied geometry_hishi_179.jpg to random_subset.
# Copied plant_rindo_24.jpg to random_subset.
# Copied object_fan_52.jpg to random_subset.
# Copied geometry_hishi_16.jpg to random_subset.
# Copied object_line_difference_1.jpg to random_subset.
# Copied plant_rindo_7.jpg to random_subset.
# Copied plant_ken_katabami_kenkatabami_46.jpg to random_subset.
# Copied geometry_ring:_itowa_itowa_11.jpg to random_subset.
# Copied plant_mokkou_43.jpg to random_subset.
# Copied object_rinpo_6.jpg to random_subset.
# Copied geometry_ring:_hosowa_hosowa_21.jpg to random_subset.
# Copied plant_gourd_gourd_hyo_gourd_hisago_7.jpg to random_subset.
# Copied object_suzu_3.jpg to random_subset.
# Copied geometry_aya_ukisen_ryo_fusen_35.jpg to random_subset.
# Copied object_kasa_umbrella_10.jpg to random_subset.
# Copied plant_ivy_25.jpg to random_subset.
# Copied plant_tachibana_12.jpg to random_subset.
# Copied plant_hiiragi_holly_2.jpg to random_subset.
# Copied object_eboshi_1.jpg to random_subset.
# Copied plant_kajikaji_leaf_kaji_27.jpg to random_subset.
# Copied geometry_hishi_70.jpg to random_subset.
# Copied geometry_corner_write_97.jpg to random_subset.
# Copied geometry_hishi_1.jpg to random_subset.
# Copied object_mari_scissors_1.jpg to random_subset.
# Copied nature_suhama_13.jpg to random_subset.
# Copied architecture_igeta_25.jpg to random_subset.
# Copied object_anchor_10.jpg to random_subset.
# Copied plant_hanabishi_36.jpg to random_subset.
# Copied plant_camellia_tsubaki_0.jpg to random_subset.
# Copied plant_tachibana_66.jpg to random_subset.
# Copied plant_hanabishi_9.jpg to random_subset.
# Copied plant_pine_matsu_19.jpg to random_subset.
# Copied plant_kashiwa_10.jpg to random_subset.
# Copied plant_sawata_omodaka_45.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_45.jpg to random_subset.
# Copied architecture_izutsu_0.jpg to random_subset.
# Copied architecture_izutsu_34.jpg to random_subset.
# Copied geometry_janome_11.jpg to random_subset.
# Copied object_nail_removal_20.jpg to random_subset.
# Copied object_arrowhead_yajiri_1.jpg to random_subset.
# Copied plant_fuji_68.jpg to random_subset.
# Copied object_flag_hata_2.jpg to random_subset.
# Copied plant_ginkgo_10.jpg to random_subset.
# Copied plant_kikyo_17.jpg to random_subset.
# Copied object_sword_ken_23.jpg to random_subset.
# Copied plant_hanabishi_97.jpg to random_subset.
# Copied architecture_izutsu_53.jpg to random_subset.
# Copied nature_cloud_spider_9.jpg to random_subset.
# Copied plant_chouji_16.jpg to random_subset.
# Copied geometry_hishi_2.jpg to random_subset.
# Copied plant_plum_37.jpg to random_subset.
# Copied object_iron_can_7.jpg to random_subset.
# Copied object_ace_masakari_8.jpg to random_subset.
# Copied object_kasegi_0.jpg to random_subset.
# Copied plant_ken_katabami_kenkatabami_15.jpg to random_subset.
# Copied plant_sawata_omodaka_16.jpg to random_subset.
# Copied object_jigami_10.jpg to random_subset.
# Copied object_fan_0.jpg to random_subset.
# Copied plant_sasa_53.jpg to random_subset.
# Copied geometry_corner_write_108.jpg to random_subset.
# Copied geometry_corner_write_22.jpg to random_subset.
# Copied object_money_zeni_5.jpg to random_subset.
# Copied plant_sasa_74.jpg to random_subset.
# Copied plant_kashiwa_8.jpg to random_subset.
# Copied object_noshi_21.jpg to random_subset.
# Copied plant_warabi_5.jpg to random_subset.
# Copied plant_sugi_8.jpg to random_subset.
# Copied plant_chrysanthemum_hear_31.jpg to random_subset.
# Copied object_jigami_8.jpg to random_subset.
# Copied geometry_meyui_43.jpg to random_subset.
# Copied object_eboshi_3.jpg to random_subset.
# Copied geometry_hishi_87.jpg to random_subset.
# Copied geometry_hishi_77.jpg to random_subset.
# Copied plant_kashiwa_50.jpg to random_subset.
# Copied plant_sasa_51.jpg to random_subset.
# Copied plant_hemp_asa_12.jpg to random_subset.
# Copied nature_suhama_4.jpg to random_subset.
# Copied plant_mokkou_31.jpg to random_subset.
# Copied geometry_ring:_itowa_itowa_101.jpg to random_subset.
# Copied object_arrow_ya_18.jpg to random_subset.
# Copied object_money_zeni_14.jpg to random_subset.
# Copied animal_butterfly_21.jpg to random_subset.
# Copied plant_kikyo_78.jpg to random_subset.
# Copied nature_daily_foot_hiashi_0.jpg to random_subset.
# Copied animal_hawk_feather_takanoha_10.jpg to random_subset.
# Copied nature_mountain_yama_5.jpg to random_subset.
# Copied object_jigami_12.jpg to random_subset.
# Copied plant_sakura_19.jpg to random_subset.
# Copied object_apricot_leaves_4.jpg to random_subset.
# Copied plant_lotus_3.jpg to random_subset.
# Copied plant_kiri_31.jpg to random_subset.
# Copied object_cotton_7.jpg to random_subset.
# Copied plant_ken_katabami_kenkatabami_4.jpg to random_subset.
# Copied nature_daily_foot_hiashi_5.jpg to random_subset.
# Copied object_kamashiki_12.jpg to random_subset.
# Copied animal_sparrow_2.jpg to random_subset.
# Copied geometry_ring:_middle_ring_nakawa_62.jpg to random_subset.
# Copied plant_kashiwa_61.jpg to random_subset.
# Copied plant_kashiwa_94.jpg to random_subset.
# Copied nature_snow_yuki_24.jpg to random_subset.
# Copied plant_myoga_31.jpg to random_subset.
# Copied object_fan_81.jpg to random_subset.
# Copied object_hagoita_6.jpg to random_subset.
# Copied plant_peony_34.jpg to random_subset.
# Copied plant_ivy_51.jpg to random_subset.
# Copied object_sword_ken_47.jpg to random_subset.
# Copied geometry_tomoe_41.jpg to random_subset.
# Copied geometry_corner_write_35.jpg to random_subset.
# Copied plant_ginkgo_37.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_31.jpg to random_subset.
# Copied plant_melon_uri_39.jpg to random_subset.
# Copied geometry_corner_write_60.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_105.jpg to random_subset.
# Copied plant_rice_ine_6.jpg to random_subset.
# Copied plant_chrysanthemum_hear_57.jpg to random_subset.
# Copied plant_walnut_0.jpg to random_subset.
# Copied object_ship_fune_1.jpg to random_subset.
# Copied plant_ran_7.jpg to random_subset.
# Copied plant_violet_sumire_4.jpg to random_subset.
# Copied animal_crane_tsuru_23.jpg to random_subset.
# Copied plant_ken_katabami_kenkatabami_6.jpg to random_subset.
# Copied object_shreddedshigiri_chigiri_7.jpg to random_subset.
# Copied object_target_mato_0.jpg to random_subset.
# Copied object_轡_bridle_2.jpg to random_subset.
# Copied plant_melon_uri_21.jpg to random_subset.
# Copied plant_plum_109.jpg to random_subset.
# Copied object_feather_hane_6.jpg to random_subset.
# Copied plant_melon_uri_52.jpg to random_subset.
# Copied geometry_shippo_26.jpg to random_subset.
# Copied geometry_ring:_middle_ring_nakawa_22.jpg to random_subset.
# Copied object_arrow_ya_36.jpg to random_subset.
# Copied plant_melon_uri_3.jpg to random_subset.
# Copied nature_star_hoshi_36.jpg to random_subset.
# Copied plant_hanabishi_64.jpg to random_subset.
# Copied plant_violet_sumire_0.jpg to random_subset.
# Copied object_arrow_ya_33.jpg to random_subset.
# Copied plant_mokkou_36.jpg to random_subset.
# Copied plant_plum_26.jpg to random_subset.
# Copied plant_ginkgo_65.jpg to random_subset.
# Copied nature_lightning_inazuma_13.jpg to random_subset.
# Copied object_fan_70.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_88.jpg to random_subset.
# Copied plant_kiri_84.jpg to random_subset.
# Copied plant_peach_1.jpg to random_subset.
# Copied geometry_hishi_105.jpg to random_subset.
# Copied plant_kiri_6.jpg to random_subset.
# Copied plant_ran_11.jpg to random_subset.
# Copied geometry_turtle_shell_62.jpg to random_subset.
# Copied geometry_hishi_62.jpg to random_subset.
# Copied plant_walnut_4.jpg to random_subset.
# Copied object_arrowhead_yajiri_5.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_64.jpg to random_subset.
# Copied plant_kikyo_95.jpg to random_subset.
# Copied letter_characters_moji_30.jpg to random_subset.
# Copied geometry_hishi_32.jpg to random_subset.
# Copied object_mari_scissors_3.jpg to random_subset.
# Copied plant_ivy_18.jpg to random_subset.
# Copied plant_plum_20.jpg to random_subset.
# Copied plant_hanakaku_27.jpg to random_subset.
# Copied geometry_hishi_140.jpg to random_subset.
# Copied plant_kashiwa_44.jpg to random_subset.
# Copied letter_characters_moji_11.jpg to random_subset.
# Copied architecture_igeta_9.jpg to random_subset.
# Copied geometry_ring:_other_wa_36.jpg to random_subset.
# Copied object_money_hei_4.jpg to random_subset.
# Copied animal_butterfly_62.jpg to random_subset.
# Copied plant_peach_2.jpg to random_subset.
# Copied plant_kiri_113.jpg to random_subset.
# Copied plant_chouji_60.jpg to random_subset.
# Copied plant_melon_uri_57.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_23.jpg to random_subset.
# Copied plant_kiri_18.jpg to random_subset.
# Copied animal_crane_tsuru_2.jpg to random_subset.
# Copied plant_pear_none_4.jpg to random_subset.
# Copied geometry_ring:_itowa_itowa_68.jpg to random_subset.
# Copied plant_plum_120.jpg to random_subset.
# Copied object_arrowhead_yajiri_9.jpg to random_subset.
# Copied plant_sakura_24.jpg to random_subset.
# Copied nature_star_hoshi_44.jpg to random_subset.
# Copied object_fan_uchiwa_1.jpg to random_subset.
# Copied plant_plum_96.jpg to random_subset.
# Copied plant_hanabishi_106.jpg to random_subset.
# Copied geometry_hishi_15.jpg to random_subset.
# Copied object_stone_12.jpg to random_subset.
# Copied geometry_ring:_other_wa_4.jpg to random_subset.
# Copied object_shreddedshigiri_chigiri_10.jpg to random_subset.
# Copied geometry_ring:_middle_ring_nakawa_59.jpg to random_subset.
# Copied plant_sawata_omodaka_12.jpg to random_subset.
# Copied plant_tachibana_31.jpg to random_subset.
# Copied architecture_izutsu_22.jpg to random_subset.
# Copied object_yabazu_yazu_7.jpg to random_subset.
# Copied object_sword_ken_114.jpg to random_subset.
# Copied plant_melon_uri_96.jpg to random_subset.
# Copied plant_nanten_nannan_1.jpg to random_subset.
# Copied geometry_ring:_other_wa_17.jpg to random_subset.
# Copied geometry_hishi_42.jpg to random_subset.
# Copied object_tree_ki_4.jpg to random_subset.
# Copied letter_characters_moji_28.jpg to random_subset.
# Copied object_stone_26.jpg to random_subset.
# Copied object_suzu_0.jpg to random_subset.
# Copied geometry_hiki_24.jpg to random_subset.
# Copied architecture_izutsu_31.jpg to random_subset.
# Copied geometry_ring:_itowa_itowa_58.jpg to random_subset.
# Copied nature_cloud_spider_5.jpg to random_subset.
# Copied plant_peony_7.jpg to random_subset.
# Copied geometry_ring:_middle_ring_nakawa_54.jpg to random_subset.
# Copied animal_butterfly_60.jpg to random_subset.
# Copied plant_ivy_62.jpg to random_subset.
# Copied plant_iron_wire_tessen_14.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_82.jpg to random_subset.
# Copied architecture_torii_4.jpg to random_subset.
# Copied geometry_tomoe_89.jpg to random_subset.
# Copied nature_kuyo_15.jpg to random_subset.
# Copied plant_kikyo_59.jpg to random_subset.
# Copied plant_sawata_omodaka_0.jpg to random_subset.
# Copied geometry_hishi_38.jpg to random_subset.
# Copied plant_matsuba_19.jpg to random_subset.
# Copied geometry_turtle_shell_77.jpg to random_subset.
# Copied nature_star_hoshi_13.jpg to random_subset.
# Copied animal_hawk_feather_takanoha_23.jpg to random_subset.
# Copied object_sword_ken_84.jpg to random_subset.
# Copied geometry_turtle_shell_29.jpg to random_subset.
# Copied letter_characters_moji_70.jpg to random_subset.
# Copied plant_ginkgo_36.jpg to random_subset.
# Copied plant_gourd_gourd_hyo_gourd_hisago_1.jpg to random_subset.
# Copied plant_kashiwa_32.jpg to random_subset.
# Copied plant_sawata_omodaka_6.jpg to random_subset.
# Copied nature_yamagata_0.jpg to random_subset.
# Copied object_apricot_leaves_33.jpg to random_subset.
# Copied animal_hawk_feather_takanoha_60.jpg to random_subset.
# Copied plant_rindo_19.jpg to random_subset.
# Copied object_yabazu_yazu_15.jpg to random_subset.
# Copied object_candle_6.jpg to random_subset.
# Copied geometry_meyui_58.jpg to random_subset.
# Copied plant_yamabuki_2.jpg to random_subset.
# Copied plant_kiri_89.jpg to random_subset.
# Copied geometry_corner_write_40.jpg to random_subset.
# Copied geometry_aya_ukisen_ryo_fusen_1.jpg to random_subset.
# Copied geometry_corner_write_118.jpg to random_subset.
# Copied plant_fuji_63.jpg to random_subset.
# Copied geometry_ring:_itowa_itowa_85.jpg to random_subset.
# Copied geometry_turtle_shell_51.jpg to random_subset.
# Copied plant_fuji_34.jpg to random_subset.
# Copied geometry_aya_ukisen_ryo_fusen_4.jpg to random_subset.
# Copied geometry_hishi_110.jpg to random_subset.
# Copied geometry_hishi_75.jpg to random_subset.
# Copied plant_sasa_67.jpg to random_subset.
# Copied plant_plum_48.jpg to random_subset.
# Copied plant_gourd_gourd_hyo_gourd_hisago_9.jpg to random_subset.
# Copied geometry_meyui_16.jpg to random_subset.
# Copied plant_tachibana_60.jpg to random_subset.
# Copied object_kamashiki_4.jpg to random_subset.
# Copied object_sword_ken_17.jpg to random_subset.
# Copied nature_snow_yuki_21.jpg to random_subset.
# Copied geometry_hishi_41.jpg to random_subset.
# Copied object_sword_ken_30.jpg to random_subset.
# Copied plant_chouji_26.jpg to random_subset.
# Copied plant_lotus_0.jpg to random_subset.
# Copied plant_kashiwa_108.jpg to random_subset.
# Copied object_sword_ken_19.jpg to random_subset.
# Copied animal_butterfly_44.jpg to random_subset.
# Copied plant_hiiragi_holly_3.jpg to random_subset.
# Copied object_arrow_ya_5.jpg to random_subset.
# Copied plant_pear_none_9.jpg to random_subset.
# Copied plant_matsuba_0.jpg to random_subset.
# Copied animal_rabbit_5.jpg to random_subset.
# Copied object_anchor_3.jpg to random_subset.
# Copied object_bottle_heishi_9.jpg to random_subset.
# Copied geometry_hishi_120.jpg to random_subset.
# Copied plant_kashiwa_102.jpg to random_subset.
# Copied geometry_ring:_other_wa_14.jpg to random_subset.
# Copied geometry_corner_write_15.jpg to random_subset.
# Copied object_apricot_leaves_20.jpg to random_subset.
# Copied letter_manji_15.jpg to random_subset.
# Copied object_car_4.jpg to random_subset.
# Copied plant_sasa_9.jpg to random_subset.
# Copied object_kanawa_12.jpg to random_subset.
# Copied object_nail_removal_7.jpg to random_subset.
# Copied plant_kiri_57.jpg to random_subset.
# Copied geometry_hishi_111.jpg to random_subset.
# Copied plant_karahana_44.jpg to random_subset.
# Copied geometry_tomoe_82.jpg to random_subset.
# Copied plant_kiri_12.jpg to random_subset.
# Copied object_tree_ki_3.jpg to random_subset.
# Copied geometry_turtle_shell_8.jpg to random_subset.
# Copied nature_yamagata_6.jpg to random_subset.
# Copied plant_melon_uri_76.jpg to random_subset.
# Copied geometry_ring:_middle_ring_nakawa_32.jpg to random_subset.
# Copied object_轡_bridle_23.jpg to random_subset.
# Copied plant_chrysanthemum_hear_20.jpg to random_subset.
# Copied geometry_ring:_middle_ring_nakawa_27.jpg to random_subset.
# Copied letter_characters_moji_12.jpg to random_subset.
# Copied nature_suhama_6.jpg to random_subset.
# Copied geometry_corner_write_92.jpg to random_subset.
# Copied plant_kashiwa_65.jpg to random_subset.
# Copied object_yabazu_yazu_0.jpg to random_subset.
# Copied plant_sawata_omodaka_29.jpg to random_subset.
# Copied object_sword_ken_77.jpg to random_subset.
# Copied object_arrowhead_yajiri_0.jpg to random_subset.
# Copied plant_pine_matsu_22.jpg to random_subset.
# Copied nature_lightning_inazuma_34.jpg to random_subset.
# Copied geometry_ring:_other_wa_46.jpg to random_subset.
# Copied plant_tachibana_13.jpg to random_subset.
# Copied object_noshi_6.jpg to random_subset.
# Copied plant_maple_maple_momiji_7.jpg to random_subset.
# Copied object_bottle_heishi_10.jpg to random_subset.
# Copied plant_kashiwa_98.jpg to random_subset.
# Copied geometry_hishi_147.jpg to random_subset.
# Copied plant_plum_123.jpg to random_subset.
# Copied geometry_hishi_90.jpg to random_subset.
# Copied plant_peony_29.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_125.jpg to random_subset.
# Copied plant_mokkou_13.jpg to random_subset.
# Copied geometry_hiki_34.jpg to random_subset.
# Copied nature_moon_tsuki_29.jpg to random_subset.
# Copied architecture_izutsu_12.jpg to random_subset.
# Copied plant_mokkou_69.jpg to random_subset.
# Copied plant_sawata_omodaka_65.jpg to random_subset.
# Copied animal_pigeon_3.jpg to random_subset.
# Copied plant_kikyo_40.jpg to random_subset.
# Copied object_arrow_ya_26.jpg to random_subset.
# Copied geometry_tomoe_70.jpg to random_subset.
# Copied plant_rindo_5.jpg to random_subset.
# Copied plant_rindo_29.jpg to random_subset.
# Copied geometry_shippo_4.jpg to random_subset.
# Copied plant_ivy_66.jpg to random_subset.
# Copied plant_plum_68.jpg to random_subset.
# Copied geometry_different_wheels_wachigai_3.jpg to random_subset.
# Copied plant_tachibana_4.jpg to random_subset.
# Copied plant_hanabishi_48.jpg to random_subset.
# Copied plant_ivy_31.jpg to random_subset.
# Copied plant_fuji_46.jpg to random_subset.
# Copied plant_plum_114.jpg to random_subset.
# Copied plant_kikyo_6.jpg to random_subset.
# Copied geometry_corner_write_13.jpg to random_subset.
# Copied geometry_ring:_itowa_itowa_10.jpg to random_subset.
# Copied geometry_tomoe_87.jpg to random_subset.
# Copied plant_karahana_8.jpg to random_subset.
# Copied plant_kikyo_28.jpg to random_subset.
# Copied geometry_tomoe_107.jpg to random_subset.
# Copied plant_ivy_12.jpg to random_subset.
# Copied plant_hanabishi_39.jpg to random_subset.
# Copied nature_suhama_31.jpg to random_subset.
# Copied object_apricot_leaves_16.jpg to random_subset.
# Copied plant_kashiwa_55.jpg to random_subset.
# Copied animal_goose_kari_10.jpg to random_subset.
# Copied architecture_torii_1.jpg to random_subset.
# Copied plant_fuji_17.jpg to random_subset.
# Copied plant_chami_chanomi_34.jpg to random_subset.
# Copied plant_tachibana_39.jpg to random_subset.
# Copied object_kuwagata_4.jpg to random_subset.
# Copied animal_goose_kari_8.jpg to random_subset.
# Copied geometry_tomoe_79.jpg to random_subset.
# Copied geometry_meyui_15.jpg to random_subset.
# Copied plant_tachibana_34.jpg to random_subset.
# Copied letter_characters_moji_36.jpg to random_subset.
# Copied plant_plum_97.jpg to random_subset.
# Copied geometry_corner_write_76.jpg to random_subset.
# Copied plant_katabami_vinegar_grass_katabami_36.jpg to random_subset.
# Copied geometry_ring:_itowa_itowa_62.jpg to random_subset.
# Copied object_sword_ken_14.jpg to random_subset.
# Copied geometry_hishi_107.jpg to random_subset.
# Copied geometry_turtle_shell_79.jpg to random_subset.
# Copied plant_chouji_48.jpg to random_subset.
# Copied letter_manji_2.jpg to random_subset.
# Copied plant_tachibana_5.jpg to random_subset.
# Copied plant_kiri_108.jpg to random_subset.
# Copied plant_kikyo_1.jpg to random_subset.
# Copied plant_matsuba_4.jpg to random_subset.
# Copied plant_karahana_51.jpg to random_subset.
# Copied object_sword_ken_9.jpg to random_subset.
# Copied plant_plum_117.jpg to random_subset.
# Copied geometry_ring:_itowa_itowa_45.jpg to random_subset.
# Copied plant_sawata_omodaka_33.jpg to random_subset.
# Copied animal_hawk_feather_takanoha_38.jpg to random_subset.
# Copied geometry_corner_write_109.jpg to random_subset.
# Copied plant_fuji_72.jpg to random_subset.
# Copied geometry_aya_ukisen_ryo_fusen_8.jpg to random_subset.
# Copied animal_butterfly_41.jpg to random_subset.
# Copied object_sword_ken_106.jpg to random_subset.
# Copied object_weight_fundo_0.jpg to random_subset.
# Copied plant_kikyo_86.jpg to random_subset.
# Copied plant_karahana_45.jpg to random_subset.
# Copied plant_maple_maple_momiji_3.jpg to random_subset.
# Copied object_sword_ken_67.jpg to random_subset.
# Copied plant_bamboo_11.jpg to random_subset.
# Copied object_cotton_3.jpg to random_subset.
# Copied plant_sasa_58.jpg to random_subset.
# Copied plant_iron_wire_tessen_3.jpg to random_subset.
# Copied plant_bamboo_10.jpg to random_subset.
# Copied animal_butterfly_6.jpg to random_subset.
# Copied animal_goose_kari_29.jpg to random_subset.
# Copied geometry_hishi_58.jpg to random_subset.
# Copied geometry_different_wheels_wachigai_13.jpg to random_subset.
# Copied object_mari_0.jpg to random_subset.
# Copied object_fan_32.jpg to random_subset.
# Copied plant_tachibana_14.jpg to random_subset.
# Copied plant_hanabishi_4.jpg to random_subset.
# Copied geometry_tomoe_40.jpg to random_subset.
# Copied animal_hawk_feather_takanoha_40.jpg to random_subset.
# Copied object_arrow_ya_14.jpg to random_subset.
# Copied nature_star_hoshi_24.jpg to random_subset.
# Copied plant_matsuba_7.jpg to random_subset.
# Copied plant_ginkgo_18.jpg to random_subset.
# Copied geometry_ring:_hosowa_hosowa_33.jpg to random_subset.
# Copied plant_chouji_31.jpg to random_subset.
# Copied plant_ivy_81.jpg to random_subset.
# Copied nature_kasumi_2.jpg to random_subset.
# Copied plant_hanabishi_30.jpg to random_subset.
# Copied nature_oboro_5.jpg to random_subset.
# Copied object_shogi_pieces_6.jpg to random_subset.
# Copied geometry_hishi_184.jpg to random_subset.
# Copied plant_plum_13.jpg to random_subset.
# Copied nature_snow_yuki_28.jpg to random_subset.
# Copied plant_hanabishi_20.jpg to random_subset.
# Copied plant_sasa_35.jpg to random_subset.
# Copied geometry_meyui_53.jpg to random_subset.
# Copied object_sword_ken_103.jpg to random_subset.
# Copied object_ring_drum_ryugo_6.jpg to random_subset.
# Copied animal_goose_kari_9.jpg to random_subset.
# Copied geometry_tomoe_68.jpg to random_subset.
# Copied plant_kashiwa_49.jpg to random_subset.
# Copied geometry_tomoe_85.jpg to random_subset.
# Copied plant_hiiragi_holly_19.jpg to random_subset.
# Copied object_hammer_tsuchi_7.jpg to random_subset.
# Copied object_sword_ken_5.jpg to random_subset.
# Copied plant_ivy_92.jpg to random_subset.
# Copied plant_pear_none_10.jpg to random_subset.
# Copied plant_hanakaku_28.jpg to random_subset.
# Copied object_ladder_3.jpg to random_subset.
