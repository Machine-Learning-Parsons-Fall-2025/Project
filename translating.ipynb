# %% [markdown]
# # Translate Japanese text into English using googletrans
# Kamon descriptions and subcategory titles are in Japanese and should be translated into english. I'm going to use the googletrans python library to do so.

# %%
from googletrans import Translator
import pandas as pd
import asyncio
import nest_asyncio

# %%
# read Kamon df
df = pd.read_csv('Data/kamon_data.csv')
df.head()

# %%
#Translate Kamon descriptions and subcategory titles from Japanese to English
translator = Translator()

async def translate_text(text):
    try:
        result = await translator.translate(text, src='ja', dest='en')
        return result.text
    except Exception as e:
        return None
    
text = df.iloc[0]["description"]
translated = await translate_text(text)
print(translated)

# %% [markdown]
# Got async translate to work, now testing below on description. Also using nest_asyncio. Instead of applying the function to each row, translate entire column and assign the result.

# %%
async def translate_column(texts):
    return [await translate_text(x) for x in texts]

nest_asyncio.apply()
loop = asyncio.get_event_loop()
df["English_Description"] = loop.run_until_complete(translate_column(df["description"]))

# %%
# HOLY SHIT SAVE THE RESULT NOW IT TOOK 37 MINUTES TO RUN
df.to_csv('Data/kamon_engdesc_only.csv', index=False)

# %%
#Get all unique subcategory titles from dataframe
unqiue_subtitles = df["subcategory_title"].unique()
unqiue_subtitles

# %%
#now translate this array
english_subtitles = loop.run_until_complete(translate_column(unqiue_subtitles))

# %%
english_subtitles
# Out:
# ['Aoi | Aoi',
#  'Hemp｜Asa',
#  'Morning glory | Morning glory',
#  'Reed | Ashi',
#  'Ayame | Ayame',
#  'Kojo | Itatori',
#  'Ginkgo | Ginkgo',
#  'Rice | Ine',
#  'Plum | Plum',
#  'Melon｜Uri',
#  'Sawata｜Omodaka',
#  'Maple｜Maple/Momiji',
#  'Persimmon | Persimmon',
#  'Moriwa | Kakitsubata',
#  'Kashiwa | Kashiwa',
#  'Kaji / Kaji leaf | Kaji',
#  'Katabami/Vinegar Grass｜Katabami',
#  'Arabesque｜Karaksa',
#  'Kikyo | Kikyo',
#  'Chrysanthemum | Hear',
#  'Kiri｜Kiri',
#  'Kudzu | Kudzu',
#  'Shoko｜Kuchinashi',
#  'Walnut | Walnut',
#  'Ken Katabami | Kenkatabami',
#  'River bone｜Kohone',
#  'Sakura｜Sakura',
#  'Sasa | Sasa',
#  'Toothpaste｜Shida',
#  'Palm | Palm',
#  'Daffodil｜Daffodil',
#  'Sugi | Sugi',
#  'Thin/Awn｜Susuki',
#  'Violet | Sumire',
#  'Ishitake｜Sekiku',
#  'Radish | Radish',
#  'Bamboo | Bamboo',
#  'Tachibana｜Tachibana',
#  'Chami | Chanomi',
#  'Chouji | Chouji',
#  'Ivy | Ivy',
#  'Camellia｜Tsubaki',
#  'Iron wire｜Tessen',
#  'Denjiso｜Denjiso',
#  'Chili pepper | Chili pepper',
#  'Nagi / Nagi',
#  'Pear | None',
#  'Sachi | Nazuna',
#  'Eggplant｜Eggplant',
#  'Nadeshiko | Nadeshiko',
#  'Nanten｜nannan',
#  'Hagi | Hagi',
#  'Basho | Basho',
#  'Lotus｜Lotus',
#  'Hanakaku | Hanakaku',
#  'Hanabishi | Hanabishi',
#  'Hiiragi | Holly',
#  'Gourd, Gourd | Hyo, Gourd, Hisago',
#  'Fuji｜Fuji',
#  'Peony | Peony',
#  'Hoya | Hoya',
#  'Pine｜Matsu',
#  'Matsuba | Matsuba',
#  'Mokkou | Mokkou',
#  'Myoga | Myoga',
#  'Karahana｜Karahana',
#  'Peach | Peach',
#  'Yamabuki | Yamabuki',
#  'Yugao｜Yugao',
#  'Ran｜Ran',
#  'Rindo｜Rindo',
#  'Warabi | Warabi',
#  'Itayagai｜Itayagai',
#  'Rabbit｜Rabbit',
#  'Horse｜Uma',
#  'Shrimp｜Shrimp',
#  'Crab | Crab',
#  'Turtle｜Turtle',
#  'Crow | Crow',
#  'Goose｜Kari',
#  'Bat｜Bat',
#  'Heron | Heron',
#  'monkey｜monkey',
#  'Sparrow | Sparrow',
#  'Hawk Feather｜Takanoha',
#  'Chidori | Chidori',
#  'butterfly｜butterfly',
#  'Antlers, deer, antlers | Tsuno, Shika, Kazuno',
#  'Crane｜Tsuru',
#  'Dragonfly｜Dragonfly',
#  'Pigeon | Pigeon',
#  'Clam｜Clam',
#  'Phoenix | Houou',
#  'Dragon｜Ryuu',
#  'Anchor | Anchor',
#  'stone',
#  'Itomaki｜Itomaki',
#  'Fan｜Uchiwa',
#  'Eboshi | Eboshi',
#  'Fan | Fan',
#  'Paddle',
#  'Mirror｜Kagami',
#  'Kasa | Umbrella',
#  'Rudder | Rudder',
#  'Kasegi｜Kasegi',
#  'Kanawa | Kanawa',
#  'Curved length｜Kanejaku',
#  'sickle | sickle',
#  'Kamashiki | Kamashiki',
#  'Iron | Can',
#  'Tree｜Ki',
#  'Pestle | Kine',
#  'Apricot leaves',
#  'Nail removal | Nail removal',
#  '轡｜bridle',
#  'Kuruko/Kuruko | Kurusu',
#  'Car｜Car',
#  'Kuwagata | Kuwagata',
#  'sword｜ken',
#  'Kenbishi | Kenbishi',
#  'Gotoku | Gotoku',
#  'Kotobashira | Kotoji',
#  'Top | Top',
#  'Sangi｜Sangi',
#  'Jigami | Jigami',
#  'Shamisen pieces | Shamisen sesame',
#  'Shogi pieces｜Shogi pieces',
#  'hood｜hood',
#  'Line difference | Line difference',
#  'Suzu | Suzu',
#  'Money｜Zeni',
#  'Treasure knot｜Takaramusubi',
#  'Jade (Jewel) | Tama',
#  'Dango｜Dango',
#  'Shredded / Shigiri | Chigiri',
#  'Chai board/beating board｜Chohan',
#  'Hammer | Tsuchi',
#  'Tsuzumi',
#  'Drum body | Tsuzumido',
#  'Noshi | Noshi',
#  'Hagoita | Hagoita',
#  'scissors | scissors',
#  'ladder | ladder',
#  'Flag｜Hata',
#  'Feather｜Hane',
#  'Habouki | Habouki',
#  'Bag｜Fukuro',
#  'Ship｜Fune',
#  'Text｜Fumi',
#  'Weight｜Fundo',
#  'Money｜Hei',
#  'Bottle｜Heishi',
#  'sail｜ho',
#  'Ace | Masakari',
#  'Masu | Masu',
#  'target｜mato',
#  'Mamezou / Mamezou',
#  'Mamori/Gion Mamori | Mamori',
#  'Mari｜Mari',
#  'Mari scissors | Mari scissors',
#  'Arrow｜Ya',
#  'Arrowhead | Yajiri',
#  'Yabazu｜Yazu',
#  'Bow｜Yumi',
#  'Ring drum｜Ryugo',
#  'Rinpo | Rinpo',
#  'Candle｜Candle',
#  'Cotton | Cotton',
#  'Hermitage | Iori',
#  'Igeta｜Igeta',
#  'Izutsu｜Izutsu',
#  'fence｜oyster',
#  'Torii｜Torii',
#  'Rokuyo | Rokuyou',
#  'Lightning｜Inazuma',
#  'Oboro｜Oboro',
#  'Kasumi | Kasumi',
#  'Cloud｜Spider',
#  'Kuyo | Kuyo',
#  'Suhama｜Suhama',
#  'Moon｜Tsuki',
#  'Wave/Wami｜Nami',
#  'Daily foot｜Hiashi',
#  'Star｜Hoshi',
#  'Mountain｜Yama',
#  'Yamagata｜Yamagata',
#  'Snow｜Yuki',
#  'Scales | Scales',
#  'Corner｜Write',
#  'Turtle shell',
#  'Shippo | Shippo',
#  'Janome | Janome',
#  'Tomoe｜Tomoe',
#  'Hiki｜Hiki',
#  'Hishi | Hishi',
#  'Aya Ukisen｜Ryo Fusen',
#  'Matsubabishi | Matsukawabishi',
#  'Murano | Murago',
#  'Meyui',
#  'Ring: Itowa | Itowa',
#  'Ring: Hosowa | Hosowa',
#  'Ring: Middle ring｜Nakawa',
#  'Ring: Thick ring | Futowa',
#  'Ring: Yukiwa | Yukiwa',
#  'Ring: Other｜Wa',
#  'Different wheels | Wachigai',
#  'Characters｜Moji',
#  'Manji | Manji']

# %%
#remove all / characters
english_subtitles_cleaned = [s.replace(' / ', '') if isinstance(s, str) else s for s in english_subtitles]
english_subtitles_cleaned
# Out:
# ['Aoi | Aoi',
#  'Hemp｜Asa',
#  'Morning glory | Morning glory',
#  'Reed | Ashi',
#  'Ayame | Ayame',
#  'Kojo | Itatori',
#  'Ginkgo | Ginkgo',
#  'Rice | Ine',
#  'Plum | Plum',
#  'Melon｜Uri',
#  'Sawata｜Omodaka',
#  'Maple｜Maple/Momiji',
#  'Persimmon | Persimmon',
#  'Moriwa | Kakitsubata',
#  'Kashiwa | Kashiwa',
#  'KajiKaji leaf | Kaji',
#  'Katabami/Vinegar Grass｜Katabami',
#  'Arabesque｜Karaksa',
#  'Kikyo | Kikyo',
#  'Chrysanthemum | Hear',
#  'Kiri｜Kiri',
#  'Kudzu | Kudzu',
#  'Shoko｜Kuchinashi',
#  'Walnut | Walnut',
#  'Ken Katabami | Kenkatabami',
#  'River bone｜Kohone',
#  'Sakura｜Sakura',
#  'Sasa | Sasa',
#  'Toothpaste｜Shida',
#  'Palm | Palm',
#  'Daffodil｜Daffodil',
#  'Sugi | Sugi',
#  'Thin/Awn｜Susuki',
#  'Violet | Sumire',
#  'Ishitake｜Sekiku',
#  'Radish | Radish',
#  'Bamboo | Bamboo',
#  'Tachibana｜Tachibana',
#  'Chami | Chanomi',
#  'Chouji | Chouji',
#  'Ivy | Ivy',
#  'Camellia｜Tsubaki',
#  'Iron wire｜Tessen',
#  'Denjiso｜Denjiso',
#  'Chili pepper | Chili pepper',
#  'NagiNagi',
#  'Pear | None',
#  'Sachi | Nazuna',
#  'Eggplant｜Eggplant',
#  'Nadeshiko | Nadeshiko',
#  'Nanten｜nannan',
#  'Hagi | Hagi',
#  'Basho | Basho',
#  'Lotus｜Lotus',
#  'Hanakaku | Hanakaku',
#  'Hanabishi | Hanabishi',
#  'Hiiragi | Holly',
#  'Gourd, Gourd | Hyo, Gourd, Hisago',
#  'Fuji｜Fuji',
#  'Peony | Peony',
#  'Hoya | Hoya',
#  'Pine｜Matsu',
#  'Matsuba | Matsuba',
#  'Mokkou | Mokkou',
#  'Myoga | Myoga',
#  'Karahana｜Karahana',
#  'Peach | Peach',
#  'Yamabuki | Yamabuki',
#  'Yugao｜Yugao',
#  'Ran｜Ran',
#  'Rindo｜Rindo',
#  'Warabi | Warabi',
#  'Itayagai｜Itayagai',
#  'Rabbit｜Rabbit',
#  'Horse｜Uma',
#  'Shrimp｜Shrimp',
#  'Crab | Crab',
#  'Turtle｜Turtle',
#  'Crow | Crow',
#  'Goose｜Kari',
#  'Bat｜Bat',
#  'Heron | Heron',
#  'monkey｜monkey',
#  'Sparrow | Sparrow',
#  'Hawk Feather｜Takanoha',
#  'Chidori | Chidori',
#  'butterfly｜butterfly',
#  'Antlers, deer, antlers | Tsuno, Shika, Kazuno',
#  'Crane｜Tsuru',
#  'Dragonfly｜Dragonfly',
#  'Pigeon | Pigeon',
#  'Clam｜Clam',
#  'Phoenix | Houou',
#  'Dragon｜Ryuu',
#  'Anchor | Anchor',
#  'stone',
#  'Itomaki｜Itomaki',
#  'Fan｜Uchiwa',
#  'Eboshi | Eboshi',
#  'Fan | Fan',
#  'Paddle',
#  'Mirror｜Kagami',
#  'Kasa | Umbrella',
#  'Rudder | Rudder',
#  'Kasegi｜Kasegi',
#  'Kanawa | Kanawa',
#  'Curved length｜Kanejaku',
#  'sickle | sickle',
#  'Kamashiki | Kamashiki',
#  'Iron | Can',
#  'Tree｜Ki',
#  'Pestle | Kine',
#  'Apricot leaves',
#  'Nail removal | Nail removal',
#  '轡｜bridle',
#  'Kuruko/Kuruko | Kurusu',
#  'Car｜Car',
#  'Kuwagata | Kuwagata',
#  'sword｜ken',
#  'Kenbishi | Kenbishi',
#  'Gotoku | Gotoku',
#  'Kotobashira | Kotoji',
#  'Top | Top',
#  'Sangi｜Sangi',
#  'Jigami | Jigami',
#  'Shamisen pieces | Shamisen sesame',
#  'Shogi pieces｜Shogi pieces',
#  'hood｜hood',
#  'Line difference | Line difference',
#  'Suzu | Suzu',
#  'Money｜Zeni',
#  'Treasure knot｜Takaramusubi',
#  'Jade (Jewel) | Tama',
#  'Dango｜Dango',
#  'ShreddedShigiri | Chigiri',
#  'Chai board/beating board｜Chohan',
#  'Hammer | Tsuchi',
#  'Tsuzumi',
#  'Drum body | Tsuzumido',
#  'Noshi | Noshi',
#  'Hagoita | Hagoita',
#  'scissors | scissors',
#  'ladder | ladder',
#  'Flag｜Hata',
#  'Feather｜Hane',
#  'Habouki | Habouki',
#  'Bag｜Fukuro',
#  'Ship｜Fune',
#  'Text｜Fumi',
#  'Weight｜Fundo',
#  'Money｜Hei',
#  'Bottle｜Heishi',
#  'sail｜ho',
#  'Ace | Masakari',
#  'Masu | Masu',
#  'target｜mato',
#  'MamezouMamezou',
#  'Mamori/Gion Mamori | Mamori',
#  'Mari｜Mari',
#  'Mari scissors | Mari scissors',
#  'Arrow｜Ya',
#  'Arrowhead | Yajiri',
#  'Yabazu｜Yazu',
#  'Bow｜Yumi',
#  'Ring drum｜Ryugo',
#  'Rinpo | Rinpo',
#  'Candle｜Candle',
#  'Cotton | Cotton',
#  'Hermitage | Iori',
#  'Igeta｜Igeta',
#  'Izutsu｜Izutsu',
#  'fence｜oyster',
#  'Torii｜Torii',
#  'Rokuyo | Rokuyou',
#  'Lightning｜Inazuma',
#  'Oboro｜Oboro',
#  'Kasumi | Kasumi',
#  'Cloud｜Spider',
#  'Kuyo | Kuyo',
#  'Suhama｜Suhama',
#  'Moon｜Tsuki',
#  'Wave/Wami｜Nami',
#  'Daily foot｜Hiashi',
#  'Star｜Hoshi',
#  'Mountain｜Yama',
#  'Yamagata｜Yamagata',
#  'Snow｜Yuki',
#  'Scales | Scales',
#  'Corner｜Write',
#  'Turtle shell',
#  'Shippo | Shippo',
#  'Janome | Janome',
#  'Tomoe｜Tomoe',
#  'Hiki｜Hiki',
#  'Hishi | Hishi',
#  'Aya Ukisen｜Ryo Fusen',
#  'Matsubabishi | Matsukawabishi',
#  'Murano | Murago',
#  'Meyui',
#  'Ring: Itowa | Itowa',
#  'Ring: Hosowa | Hosowa',
#  'Ring: Middle ring｜Nakawa',
#  'Ring: Thick ring | Futowa',
#  'Ring: Yukiwa | Yukiwa',
#  'Ring: Other｜Wa',
#  'Different wheels | Wachigai',
#  'Characters｜Moji',
#  'Manji | Manji']

# %%
# put this after the next cell
df['English_Subcategory'] = df['subcategory_title'].map(dict(zip(unqiue_subtitles, english_subtitles_cleaned)))

# %%
df.head()
# Out:
#                                           image_link description  \
# 0  https://kamondb.com/wp/wp-content/uploads/2019...         徳川葵
# 1  https://kamondb.com/wp/wp-content/uploads/2019...        剣三つ葵
# 2  https://kamondb.com/wp/wp-content/uploads/2019...         立ち葵
# 3  https://kamondb.com/wp/wp-content/uploads/2019...       丸に立ち葵
# 4  https://kamondb.com/wp/wp-content/uploads/2019...       水に立ち葵
#
#   subcategory_title category_title        English_Description  \
# 0           葵 | あおい          plant               Aoi Tokugawa
# 1           葵 | あおい          plant            sword three Aoi
# 2           葵 | あおい          plant         standing hollyhock
# 3           葵 | あおい          plant   Aoi standing in a circle
# 4           葵 | あおい          plant  Aoi standing in the water
#
#   English_Subcategory_Title English_Subcategory
# 0                 Aoi | Aoi           Aoi | Aoi
# 1                 Aoi | Aoi           Aoi | Aoi
# 2                 Aoi | Aoi           Aoi | Aoi
# 3                 Aoi | Aoi           Aoi | Aoi
# 4                 Aoi | Aoi           Aoi | Aoi

# %%
#final save
df.to_csv('Data/kamon_english.csv', index=False)

# %% [markdown]
# ### Tried something different below:

# %%
from deep_translator import GoogleTranslator

# %%
test = (df.iloc[0]["description"])
translated_test = GoogleTranslator(source='ja', target='en').translate(test)
print(test)
print(translated_test)

# %% [markdown]
# Below may take a while to run.

# %%
#Run across entire dataframe
df["English_Description"] = df["description"].apply(lambda x: GoogleTranslator(source='ja', target='en').translate(x))

# %% [markdown]
# Failed!
#
# TranslationNotFound: 石持ち地抜き抱き茗荷 --> No translation was found using the current translator. Try another translator?

# %%
df.head()
